# %%
import pandas as pd

# %%
def create_dummy_columns(df, column_name):
    return pd.get_dummies(df, columns=[column_name], prefix=column_name)

# %%
profile = pd.read_json('../data/profile.json', orient='records', lines=True)
profile.head()
# Out:
#   gender  age                                id  became_member_on    income
# 0   None  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1      F   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2   None  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3      F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4   None  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN

# %%
profile = create_dummy_columns(profile,"gender")
profile.head()
# Out:
#    age                                id  became_member_on    income  \
# 0  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN
#
#    gender_F  gender_M  gender_O
# 0     False     False     False
# 1      True     False     False
# 2     False     False     False
# 3      True     False     False
# 4     False     False     False

# %%
# Convert became_member_on to datetime and create new column
profile['become_member_on_date'] = pd.to_datetime(profile['became_member_on'], format='%Y%m%d')
profile.head()
# Out:
#    age                                id  became_member_on    income  \
# 0  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN
#
#    gender_F  gender_M  gender_O become_member_on_date
# 0     False     False     False            2017-02-12
# 1      True     False     False            2017-07-15
# 2     False     False     False            2018-07-12
# 3      True     False     False            2017-05-09
# 4     False     False     False            2017-08-04

# %%
# Get the latest membership date
latest_date = profile['became_member_on_date'].max()
print(latest_date)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'became_member_on_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Get the latest membership date
# ----> 2 latest_date = profile['became_member_on_date'].max()
#       3 print(latest_date)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'became_member_on_date'

# %%
# Apply the function to create a new column with list of dates
profile['days_since_last_member'] = profile['became_member_on']

profile.head()
# Out:
#    age                                id  became_member_on    income  \
# 0  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN
#
#    gender_F  gender_M  gender_O  \
# 0     False     False     False
# 1      True     False     False
# 2     False     False     False
# 3      True     False     False
# 4     False     False     False
#
#                                                  new  days_since_last_member
# 0  DatetimeIndex(['1970-01-01 00:00:00.020170212'...                20170212
# 1  DatetimeIndex(['1970-01-01 00:00:00.020170715'...                20170715
# 2  DatetimeIndex(['1970-01-01 00:00:00.020180712'...                20180712
# 3  DatetimeIndex(['1970-01-01 00:00:00.020170509'...                20170509
# 4  DatetimeIndex(['1970-01-01 00:00:00.020170804'...                20170804

# %%
portfolio = pd.read_json('../data/portfolio.json', orient='records', lines=True)
portfolio.head()
# Out:
#    reward                      channels  difficulty  duration     offer_type  \
# 0      10       [email, mobile, social]          10         7           bogo
# 1      10  [web, email, mobile, social]          10         5           bogo
# 2       0          [web, email, mobile]           0         4  informational
# 3       5          [web, email, mobile]           5         7           bogo
# 4       5                  [web, email]          20        10       discount
#
#                                  id
# 0  ae264e3637204a6fb9bb56bc8210ddfd
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0
# 2  3f207df678b143eea3cee63160fa8bed
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7

# %%
user_behaviour = pd.read_csv('../data/features/user_behaviour.csv')
user_behaviour.head()
# Out:
#                          profile_id           event  time  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received     0
# 1  a03223e636434f42ac4c3df47e8bac43  offer received     0
# 2  e2127556f4f64592b11af22de27a7932  offer received     0
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received     0
# 4  68617ca6246f4fbc85e91a2a49552598  offer received     0
#
#                        portfolio_id  amount  reward_x  reward_y  \
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN       NaN       5.0
# 1  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       NaN       5.0
# 2  2906b810c7d4411798c6938adc9daaa5     NaN       NaN       2.0
# 3  fafdcd668e3743c1bb461111dcafc2a4     NaN       NaN       2.0
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN       NaN      10.0
#
#                                channels  difficulty  duration offer_type  \
# 0            ['web', 'email', 'mobile']         5.0       7.0       bogo
# 1                      ['web', 'email']        20.0      10.0   discount
# 2            ['web', 'email', 'mobile']        10.0       7.0   discount
# 3  ['web', 'email', 'mobile', 'social']        10.0      10.0   discount
# 4  ['web', 'email', 'mobile', 'social']        10.0       5.0       bogo
#
#   gender  age  became_member_on    income
# 0      F   75          20170509  100000.0
# 1    NaN  118          20170804       NaN
# 2      M   68          20180426   70000.0
# 3    NaN  118          20170925       NaN
# 4    NaN  118          20171002       NaN
