# %%
import pandas as pd

# %%
def create_dummy_columns(df, column_name):
    return pd.get_dummies(df, columns=[column_name], prefix=column_name)

# %% [markdown]
# ## Profile

# %%
profile = pd.read_json('../data/profile.json', orient='records', lines=True)
profile.head()
# Out:
#   gender  age                                id  became_member_on    income
# 0   None  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1      F   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2   None  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3      F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4   None  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN

# %%
# Convert gender to dummies
profile = create_dummy_columns(profile,"gender")
profile.head()
# Out:
#    age                                id  became_member_on    income  \
# 0  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN
#
#    gender_F  gender_M  gender_O
# 0     False     False     False
# 1      True     False     False
# 2     False     False     False
# 3      True     False     False
# 4     False     False     False

# %%
# Convert became_member_on to datetime and create new column
profile['become_member_on_date'] = pd.to_datetime(profile['became_member_on'], format='%Y%m%d')
profile.head()
# Out:
#    age                                id  became_member_on    income  \
# 0  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN
#
#    gender_F  gender_M  gender_O become_member_on_date
# 0     False     False     False            2017-02-12
# 1      True     False     False            2017-07-15
# 2     False     False     False            2018-07-12
# 3      True     False     False            2017-05-09
# 4     False     False     False            2017-08-04

# %%
# Get the latest membership date
latest_date = profile['become_member_on_date'].max()
print(latest_date)
# Out:
# 2018-07-26 00:00:00

# %%
# Apply the function to create a new column with list of dates
profile['days_since_last_member'] = (latest_date - profile['become_member_on_date']).dt.days
profile.head()
# Out:
#    age                                id  became_member_on    income  \
# 0  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN
#
#    gender_F  gender_M  gender_O become_member_on_date  days_since_last_member
# 0     False     False     False            2017-02-12                     529
# 1      True     False     False            2017-07-15                     376
# 2     False     False     False            2018-07-12                      14
# 3      True     False     False            2017-05-09                     443
# 4     False     False     False            2017-08-04                     356

# %% [markdown]
# ## Portfolio

# %%
portfolio = pd.read_json('../data/portfolio.json', orient='records', lines=True)
portfolio.head()
# Out:
#    reward                      channels  difficulty  duration     offer_type  \
# 0      10       [email, mobile, social]          10         7           bogo
# 1      10  [web, email, mobile, social]          10         5           bogo
# 2       0          [web, email, mobile]           0         4  informational
# 3       5          [web, email, mobile]           5         7           bogo
# 4       5                  [web, email]          20        10       discount
#
#                                  id
# 0  ae264e3637204a6fb9bb56bc8210ddfd
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0
# 2  3f207df678b143eea3cee63160fa8bed
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7

# %%
# Convert offer_type to dummies
portfolio = create_dummy_columns(portfolio,"offer_type")
portfolio.head()
# Out:
#    reward                      channels  difficulty  duration  \
# 0      10       [email, mobile, social]          10         7
# 1      10  [web, email, mobile, social]          10         5
# 2       0          [web, email, mobile]           0         4
# 3       5          [web, email, mobile]           5         7
# 4       5                  [web, email]          20        10
#
#                                  id  offer_type_bogo  offer_type_discount  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd             True                False
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0             True                False
# 2  3f207df678b143eea3cee63160fa8bed            False                False
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9             True                False
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7            False                 True
#
#    offer_type_informational
# 0                     False
# 1                     False
# 2                      True
# 3                     False
# 4                     False

# %%
# First, explode the array column to get one row per channel
channels_dummies = pd.get_dummies(portfolio['channels'].explode(), prefix='channel')

# Then aggregate back to get one row per original record
channels_dummies = channels_dummies.groupby(level=0).max()

# Join the dummy columns back to the original dataframe
portfolio = portfolio.join(channels_dummies)

portfolio.head()
# Out:
#    reward                      channels  difficulty  duration  \
# 0      10       [email, mobile, social]          10         7
# 1      10  [web, email, mobile, social]          10         5
# 2       0          [web, email, mobile]           0         4
# 3       5          [web, email, mobile]           5         7
# 4       5                  [web, email]          20        10
#
#                                  id  offer_type_bogo  offer_type_discount  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd             True                False
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0             True                False
# 2  3f207df678b143eea3cee63160fa8bed            False                False
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9             True                False
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7            False                 True
#
#    offer_type_informational  channel_email  channel_mobile  channel_social  \
# 0                     False           True            True            True
# 1                     False           True            True            True
# 2                      True           True            True           False
# 3                     False           True            True           False
# 4                     False           True           False           False
#
#    channel_web
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True

# %% [markdown]
# ## Transcript

# %%
transcript = pd.read_json('../data/transcript.json', orient='records', lines=True)
transcript.head()
# Out:
#                              person           event  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1  a03223e636434f42ac4c3df47e8bac43  offer received
# 2  e2127556f4f64592b11af22de27a7932  offer received
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4  68617ca6246f4fbc85e91a2a49552598  offer received
#
#                                               value  time
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}     0
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0

# %%
# Replace the current unnesting code with this:
def extract_value_fields(row):
    if isinstance(row['value'], dict):
        return pd.Series({
            'offer_id': row['value'].get('offer id', None),
            'amount': row['value'].get('amount', None),
            'reward': row['value'].get('reward', None)
        })
    return pd.Series({'offer_id': None, 'amount': None, 'reward': None})

# Create new columns by applying the function
value_columns = transcript.apply(extract_value_fields, axis=1)
transcript = pd.concat([transcript, value_columns], axis=1)

# Display the first few rows of the transformed dataset
transcript.head()
# Out:
#                              person           event  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1  a03223e636434f42ac4c3df47e8bac43  offer received
# 2  e2127556f4f64592b11af22de27a7932  offer received
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4  68617ca6246f4fbc85e91a2a49552598  offer received
#
#                                               value  time  \
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}     0
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0
#
#                            offer_id  amount  reward
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     NaN
# 1  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN
# 2  2906b810c7d4411798c6938adc9daaa5     NaN     NaN
# 3  fafdcd668e3743c1bb461111dcafc2a4     NaN     NaN
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN     NaN

# %% [markdown]
# ## User Behaviour

# %%
transcript = transcript.rename(columns={'offer_id': 'portfolio_id','person':'profile_id'})
profile = profile.rename(columns={'id': 'profile_id'})
portfolio = portfolio.rename(columns={'id': 'portfolio_id'})

# %%
user_behaviour = pd.merge(transcript ,portfolio, on="portfolio_id", how="left")
user_behaviour = pd.merge(user_behaviour,profile, on="profile_id", how="left")
user_behaviour.head()
# Out:
#                          profile_id           event  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1  a03223e636434f42ac4c3df47e8bac43  offer received
# 2  e2127556f4f64592b11af22de27a7932  offer received
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4  68617ca6246f4fbc85e91a2a49552598  offer received
#
#                                               value  time  \
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}     0
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0
#
#                        portfolio_id  amount  reward_x  reward_y  \
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN       NaN       5.0
# 1  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN       NaN       5.0
# 2  2906b810c7d4411798c6938adc9daaa5     NaN       NaN       2.0
# 3  fafdcd668e3743c1bb461111dcafc2a4     NaN       NaN       2.0
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN       NaN      10.0
#
#                        channels  difficulty  ...  channel_social channel_web  \
# 0          [web, email, mobile]         5.0  ...           False        True
# 1                  [web, email]        20.0  ...           False        True
# 2          [web, email, mobile]        10.0  ...           False        True
# 3  [web, email, mobile, social]        10.0  ...            True        True
# 4  [web, email, mobile, social]        10.0  ...            True        True
#
#    age became_member_on    income gender_F gender_M gender_O  \
# 0   75         20170509  100000.0     True    False    False
# 1  118         20170804       NaN    False    False    False
# 2   68         20180426   70000.0    False     True    False
# 3  118         20170925       NaN    False    False    False
# 4  118         20171002       NaN    False    False    False
#
#    become_member_on_date  days_since_last_member
# 0             2017-05-09                     443
# 1             2017-08-04                     356
# 2             2018-04-26                      91
# 3             2017-09-25                     304
# 4             2017-10-02                     297
#
# [5 rows x 26 columns]

# %%
user_behaviour = user_behaviour.drop(["event", "value", "portfolio_id","channels","became_member_on"], axis='columns',)
user_behaviour.head()
# Out:
#                          profile_id  time  amount  reward_x  reward_y  \
# 0  78afa995795e4d85b5d9ceeca43f5fef     0     NaN       NaN       5.0
# 1  a03223e636434f42ac4c3df47e8bac43     0     NaN       NaN       5.0
# 2  e2127556f4f64592b11af22de27a7932     0     NaN       NaN       2.0
# 3  8ec6ce2a7e7949b1bf142def7d0e0586     0     NaN       NaN       2.0
# 4  68617ca6246f4fbc85e91a2a49552598     0     NaN       NaN      10.0
#
#    difficulty  duration offer_type_bogo offer_type_discount  \
# 0         5.0       7.0            True               False
# 1        20.0      10.0           False                True
# 2        10.0       7.0           False                True
# 3        10.0      10.0           False                True
# 4        10.0       5.0            True               False
#
#   offer_type_informational  ... channel_mobile channel_social channel_web  \
# 0                    False  ...           True          False        True
# 1                    False  ...          False          False        True
# 2                    False  ...           True          False        True
# 3                    False  ...           True           True        True
# 4                    False  ...           True           True        True
#
#    age    income  gender_F  gender_M  gender_O  become_member_on_date  \
# 0   75  100000.0      True     False     False             2017-05-09
# 1  118       NaN     False     False     False             2017-08-04
# 2   68   70000.0     False      True     False             2018-04-26
# 3  118       NaN     False     False     False             2017-09-25
# 4  118       NaN     False     False     False             2017-10-02
#
#   days_since_last_member
# 0                    443
# 1                    356
# 2                     91
# 3                    304
# 4                    297
#
# [5 rows x 21 columns]

# %%
group_by = [
    'profile_id', 
    'age', 
    'income', 
    'gender_F',
    'gender_M', 
    'gender_O', 
    'become_member_on_date',
    'days_since_last_member'
    ]

aggregated_columns = list(set(user_behaviour.columns)-set(group_by))

# %%
user_behaviour_grouped = user_behaviour.groupby(group_by)[aggregated_columns].sum().reset_index()
user_behaviour_grouped.head()
# Out:
#                          profile_id  age   income  gender_F  gender_M  \
# 0  0009655768c64bdeb2e877511632db8f   33  72000.0     False      True
# 1  0011e0d4e6b944f998e987f904e8c1e5   40  57000.0     False     False
# 2  0020c2b971eb4e9188eac86d93036a77   59  90000.0      True     False
# 3  0020ccbbb6d84e358d3414a3ff76cffd   24  60000.0      True     False
# 4  003d66b6608740288d6cc97a6903f4f0   26  73000.0      True     False
#
#    gender_O become_member_on_date  days_since_last_member  reward_y  \
# 0     False            2017-04-21                     461      16.0
# 1      True            2018-01-09                     198      26.0
# 2     False            2016-03-04                     874      36.0
# 3     False            2016-11-11                     622      26.0
# 4     False            2017-06-21                     400      13.0
#
#    difficulty  ... channel_web   time  channel_mobile  \
# 0        40.0  ...           7   9414               9
# 1        64.0  ...           8   6570               8
# 2        60.0  ...           5   6378               8
# 3        34.0  ...           6   8622               8
# 4        60.0  ...           7  11718               8
#
#   offer_type_informational  amount  offer_type_discount channel_social  \
# 0                        4  127.60                    3              6
# 1                        4   79.46                    4              4
# 2                        2  196.86                    3              8
# 3                        2  154.05                    2              6
# 4                        4   48.34                    5              6
#
#   duration  channel_email reward_x
# 0     51.0              9      9.0
# 1     62.0             10     13.0
# 2     53.0              8     14.0
# 3     44.0              8     13.0
# 4     64.0              9      9.0
#
# [5 rows x 21 columns]

# %%
user_behaviour_grouped.to_csv("../data/features/user_behaviour.csv", index=False)
