# %%
import pandas as pd

# %%
def create_dummy_columns(df, column_name):
    return pd.get_dummies(df, columns=[column_name], prefix=column_name)

# %% [markdown]
# ## Profile

# %%
profile = pd.read_json('../data/profile.json', orient='records', lines=True)
profile.head()
# Out:
#   gender  age                                id  became_member_on    income
# 0   None  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1      F   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2   None  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3      F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4   None  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN

# %%
# Convert gender to dummies
profile = create_dummy_columns(profile,"gender")
profile.head()
# Out:
#    age                                id  became_member_on    income  \
# 0  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN
#
#    gender_F  gender_M  gender_O
# 0     False     False     False
# 1      True     False     False
# 2     False     False     False
# 3      True     False     False
# 4     False     False     False

# %%
# Convert became_member_on to datetime and create new column
profile['become_member_on_date'] = pd.to_datetime(profile['became_member_on'], format='%Y%m%d')
profile.head()
# Out:
#    age                                id  became_member_on    income  \
# 0  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN
#
#    gender_F  gender_M  gender_O become_member_on_date
# 0     False     False     False            2017-02-12
# 1      True     False     False            2017-07-15
# 2     False     False     False            2018-07-12
# 3      True     False     False            2017-05-09
# 4     False     False     False            2017-08-04

# %%
# Get the latest membership date
latest_date = profile['become_member_on_date'].max()
print(latest_date)
# Out:
# 2018-07-26 00:00:00

# %%
# Apply the function to create a new column with list of dates
profile['days_since_last_member'] = (latest_date - profile['become_member_on_date']).dt.days
profile.head()
# Out:
#    age                                id  became_member_on    income  \
# 0  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN
#
#    gender_F  gender_M  gender_O become_member_on_date  days_since_last_member
# 0     False     False     False            2017-02-12                     529
# 1      True     False     False            2017-07-15                     376
# 2     False     False     False            2018-07-12                      14
# 3      True     False     False            2017-05-09                     443
# 4     False     False     False            2017-08-04                     356
